# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib
from sklearn.metrics import roc_curve, auc
import seaborn as sns

import lightgbm as lgb
import utils

#supression warnings
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
data_path = './data/jlr_all_user_processed.xlsx'
df = pd.read_excel(data_path)
df.head(3)
# Out:
#       user_id  follow_count  fans_count  gender birthday  location  level  \
# 0     oden123             0           0       2      NaT         1      1
# 1   生活1934626             2           4       2      NaT         2      1
# 2  wangzi1125             0           1       2      NaT         3      1
#
#   registration_time  properties  mileage     ...      \
# 0        2018-03-26           1     4430     ...
# 1        2012-05-07           1     4270     ...
# 2        2017-06-18           1     2090     ...
#
#                                      car_friend_zone label car_like  \
# 0                                                NaN  True        1
# 1  [{'名称': '汽车之家甘肃论坛车友会', '人数': 672, '创建时间': '201...  True        2
# 2                                                NaN  True        3
#
#   excellent_post_count all_post_count  regis_year  regis_month  regis_day  \
# 0                    0              0        2018            3          3
# 1                    0              0        2012            5          5
# 2                    0              1        2017            6          6
#
#         date  date_delta
# 0 2018-03-26        4522
# 1 2012-05-07        2373
# 2 2017-06-18        4241
#
# [3 rows x 24 columns]

# %%
# df.keys(), df.dtypes

# %% [markdown]
# ### Data choosing
# we choose some features to build the machine learning model

# %%
x = df.drop(columns=[
                      'user_id',
#                      'follow_count',
#                      'fans_count', 
                     'gender', 
                      'birthday',
#                      'location',
                     'level',
                      'registration_time',
                     'properties',
#                      'mileage',
                      'post',
                      'cars',
                      'koubei_post',
                      'gas_mileage',
                      'car_friend_zone',
                      'label',
#                      'car_like', 
                     'excellent_post_count',
#                      'all_post_count',
                      'regis_year',
                      'regis_month',
                      'regis_day', 
                      'date',
#                      'date_delta'
                     ])
x.head(2)
# Out:
#    follow_count  fans_count  location  mileage  car_like  all_post_count  \
# 0             0           0         1     4430         1               0
# 1             2           4         2     4270         2               0
#
#    date_delta
# 0        4522
# 1        2373

# %%
# faeture heat map
import matplotlib.pyplot as plt
import seaborn as sns
# data = pd.read_csv("../input/car_crashes.csv")
data = x.corr()
sns.heatmap(data)
plt.show()

# %%
y = df['label'].astype('uint8')
utils.exploreCat(df, 'label')
# Out:
# <div id="ccddad17-1048-4c31-a356-1d42696aeb37" style="height: 400px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'ccddad17-1048-4c31-a356-1d42696aeb37',
#             [{"hoverinfo": "all", "labels": [false, true], "marker": {"colors": ["#96D38C", "#FEBFB3"], "line": {"color": "#fff", "width": 2}}, "textfont": {"size": 12}, "textinfo": "value", "values": [4830.0, 725.0], "type": "pie", "uid": "100b9cb4-aa09-11e8-b6ce-6c40089fb510"}],
#             {"height": 400, "title": "label"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('ccddad17-1048-4c31-a356-1d42696aeb37',{});}).then(function(){Plotly.animate('ccddad17-1048-4c31-a356-1d42696aeb37');})
#         });</script>

# %%
# dataset size
_x, _y = np.array(x).astype('int'), np.array(y).astype('int')
_x.shape, _y.shape
# Out:
# ((5555, 7), (5555,))

# %% [markdown]
# ### Split dataset into train/validation/test set
# train:validation:test = 8:1:1

# %%
x_train, x_test, y_train, y_test = train_test_split(_x, _y, test_size=0.2,  random_state = 42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5,  random_state = 42)

# %%
print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (4444, 7) (555, 7) (556, 7)

# %%
# positive/negative propotion in dataset
print("In train set, positive : negative = {}:{}=1:{} ".format(sum(y_train==1),sum(y_train==0), sum(y_train==0)/sum(y_train==1)))
print("In validation set, positive : negative = {}:{}=1:{}".format(sum(y_val==1),sum(y_val==0), sum(y_val==0)/sum(y_val==1)))
print("In test set, positive : negative = {}:{}=1:{}".format(sum(y_test==1),sum(y_test==0),sum(y_test==0)/sum(y_test==1)))
# Out:
# In train set, positive : negative = 578:3866=1:6.688581314878893
# In validation set, positive : negative = 67:488=1:7.2835820895522385
# In test set, positive : negative = 80:476=1:5.95

# %% [markdown]
# ### Build SVM model then train with above dataset

# %%
clf = SVC(C=0.8, kernel='rbf', class_weight='balanced')

# %%
clf.fit(x_train, y_train)
# Out:
# SVC(C=0.8, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred = clf.predict(x_test)

# %%
print(classification_report(y_true=y_test, y_pred=pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.92      0.88       476
#           1       0.03      0.01      0.02        80
#
# avg / total       0.73      0.79      0.76       556

# %% [markdown]
# ### Build lightgbm model and train with above dataset

# %%
# Lightgbm dataset construction

# train_data = lgb.Dataset(x_train, label=y_train)
# val_data = lgb.Dataset(x_val, label=y_val)
# test_data = lgb.Dataset(x_test, label = y_test)

feature_name = list(x.keys())
categorical_feature = [
#                        'gender',
                       'location',
#                        'level', 
#                        'properties', 
                       'car_like',
                     #'regis_year', 'regis_month', 'regis_day',
                                            ]
train_data = lgb.Dataset(x_train, 
                         label=y_train,
                         feature_name=feature_name,
                         categorical_feature=categorical_feature,
                        )
val_data = lgb.Dataset(x_val,
                       label=y_val,
                       feature_name=feature_name,
                       categorical_feature=categorical_feature,
                      )
test_data = lgb.Dataset(x_test, 
                        label = y_test,
                        feature_name=feature_name,
                        categorical_feature=categorical_feature,
                       )
# feature_name, categorical_feature

# %% [markdown]
# #### Setting parameters

# %%
# para searching
params = {
    'boosting_type': 'gbdt',  # np.random.choice(['dart', 'gbdt']),
    'objective': 'binary',
    'metric': ['binary_logloss', 'auc'], 
    
    'learning_rate': 0.25,
    
    'num_leaves': np.random.randint(20,23),
    'max_depth': np.random.randint(8,10),
    'min_data_in_leaf': int(2 ** (np.random.rand()*1.5 + 5)),
    
    'feature_fraction': np.random.rand()*0.35+0.65,
    'bagging_fraction': np.random.rand()*0.35+0.65,
    'bagging_freq': 1,
    
    'lambda_l1': 10 ** (np.random.rand() * 2),
    'lambda_l2': 10 ** (np.random.rand() * 3 + 2),
    'min_gain_to_split': 0.0,
    'min_sum_hessian_in_leaf': 0.1,
    
    'num_threads': 16,
    'verbose': 0,
    'is_training_metric': 'True'
}
print('Hyper-parameters:')
print(params)
# Out:
# Hyper-parameters:
# {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['binary_logloss', 'auc'], 'learning_rate': 0.25, 'num_leaves': 20, 'max_depth': 9, 'min_data_in_leaf': 82, 'feature_fraction': 0.9565605257040268, 'bagging_fraction': 0.9395391896439496, 'bagging_freq': 1, 'lambda_l1': 3.774075427859307, 'lambda_l2': 3543.603834642538, 'min_gain_to_split': 0.0, 'min_sum_hessian_in_leaf': 0.1, 'num_threads': 16, 'verbose': 0, 'is_training_metric': 'True'}

# %% [markdown]
# #### Training

# %%
evals_result = {}  # dict to store evaluation results of all the items in `valid_sets`

gbm = lgb.train(params, 
                train_data, 
                num_boost_round=10000, 
                valid_sets=[train_data, val_data], 
                valid_names = ['train', 'valid'], 
                evals_result=evals_result, 
                early_stopping_rounds=3000, 
                verbose_eval=100)
# Out:
# Training until validation scores don't improve for 3000 rounds.
# [100]	train's auc: 0.806622	train's binary_logloss: 0.332191	valid's auc: 0.714078	valid's binary_logloss: 0.334034
# [200]	train's auc: 0.821751	train's binary_logloss: 0.312268	valid's auc: 0.728377	valid's binary_logloss: 0.323662
# [300]	train's auc: 0.832637	train's binary_logloss: 0.300483	valid's auc: 0.737858	valid's binary_logloss: 0.317334
# [400]	train's auc: 0.841737	train's binary_logloss: 0.292332	valid's auc: 0.741987	valid's binary_logloss: 0.314085
# [500]	train's auc: 0.849073	train's binary_logloss: 0.286209	valid's auc: 0.743363	valid's binary_logloss: 0.312129
# [600]	train's auc: 0.855023	train's binary_logloss: 0.28123	valid's auc: 0.74318	valid's binary_logloss: 0.310918
# [700]	train's auc: 0.860465	train's binary_logloss: 0.277103	valid's auc: 0.743485	valid's binary_logloss: 0.310281
# [800]	train's auc: 0.865256	train's binary_logloss: 0.273506	valid's auc: 0.744281	valid's binary_logloss: 0.30967
# [900]	train's auc: 0.869417	train's binary_logloss: 0.270416	valid's auc: 0.743791	valid's binary_logloss: 0.309634
# [1000]	train's auc: 0.873259	train's binary_logloss: 0.267618	valid's auc: 0.743241	valid's binary_logloss: 0.309862
# [1100]	train's auc: 0.877107	train's binary_logloss: 0.264921	valid's auc: 0.743302	valid's binary_logloss: 0.310187
# [1200]	train's auc: 0.880609	train's binary_logloss: 0.262402	valid's auc: 0.741436	valid's binary_logloss: 0.310717
# [1300]	train's auc: 0.883973	train's binary_logloss: 0.260087	valid's auc: 0.74217	valid's binary_logloss: 0.310814
# [1400]	train's auc: 0.887244	train's binary_logloss: 0.257745	valid's auc: 0.741589	valid's binary_logloss: 0.311293
# [1500]	train's auc: 0.8903	train's binary_logloss: 0.255667	valid's auc: 0.740886	valid's binary_logloss: 0.31192
# [1600]	train's auc: 0.893331	train's binary_logloss: 0.253565	valid's auc: 0.739724	valid's binary_logloss: 0.312594
# [1700]	train's auc: 0.896043	train's binary_logloss: 0.251606	valid's auc: 0.739724	valid's binary_logloss: 0.313357
# [1800]	train's auc: 0.898632	train's binary_logloss: 0.249778	valid's auc: 0.738561	valid's binary_logloss: 0.314096
# [1900]	train's auc: 0.901054	train's binary_logloss: 0.247973	valid's auc: 0.737521	valid's binary_logloss: 0.314723
# [2000]	train's auc: 0.903593	train's binary_logloss: 0.246226	valid's auc: 0.736237	valid's binary_logloss: 0.315561
# [2100]	train's auc: 0.905819	train's binary_logloss: 0.244537	valid's auc: 0.735319	valid's binary_logloss: 0.316304
# [2200]	train's auc: 0.9078	train's binary_logloss: 0.242962	valid's auc: 0.734555	valid's binary_logloss: 0.317088
# [2300]	train's auc: 0.909737	train's binary_logloss: 0.24138	valid's auc: 0.734096	valid's binary_logloss: 0.317907
# [2400]	train's auc: 0.912086	train's binary_logloss: 0.239709	valid's auc: 0.733759	valid's binary_logloss: 0.31887
# [2500]	train's auc: 0.913881	train's binary_logloss: 0.238223	valid's auc: 0.733362	valid's binary_logloss: 0.319567
# [2600]	train's auc: 0.915708	train's binary_logloss: 0.23677	valid's auc: 0.732322	valid's binary_logloss: 0.320494
# [2700]	train's auc: 0.917388	train's binary_logloss: 0.235376	valid's auc: 0.731557	valid's binary_logloss: 0.321297
# [2800]	train's auc: 0.91895	train's binary_logloss: 0.234034	valid's auc: 0.73116	valid's binary_logloss: 0.322107
# [2900]	train's auc: 0.920506	train's binary_logloss: 0.232689	valid's auc: 0.729569	valid's binary_logloss: 0.323096
# [3000]	train's auc: 0.921985	train's binary_logloss: 0.231375	valid's auc: 0.729722	valid's binary_logloss: 0.323754
# [3100]	train's auc: 0.923345	train's binary_logloss: 0.230221	valid's auc: 0.72908	valid's binary_logloss: 0.324431
# [3200]	train's auc: 0.924508	train's binary_logloss: 0.229054	valid's auc: 0.728621	valid's binary_logloss: 0.325165
# [3300]	train's auc: 0.925794	train's binary_logloss: 0.227872	valid's auc: 0.728529	valid's binary_logloss: 0.325909
# [3400]	train's auc: 0.926869	train's binary_logloss: 0.226789	valid's auc: 0.728224	valid's binary_logloss: 0.326609
# [3500]	train's auc: 0.928125	train's binary_logloss: 0.225669	valid's auc: 0.727459	valid's binary_logloss: 0.327322
# [3600]	train's auc: 0.929396	train's binary_logloss: 0.224505	valid's auc: 0.727	valid's binary_logloss: 0.328025
# [3700]	train's auc: 0.930445	train's binary_logloss: 0.223529	valid's auc: 0.726389	valid's binary_logloss: 0.328864
# Early stopping, best iteration is:
# [789]	train's auc: 0.86469	train's binary_logloss: 0.273866	valid's auc: 0.744801	valid's binary_logloss: 0.309674

# %%
train_auc_log = evals_result['train']['binary_logloss']
# type(train_auc_log)
# len(train_auc_log)
val_auc_log = evals_result['valid']['binary_logloss']

# plot training logs
plt.figure()
plt.rcParams['savefig.dpi'] = 50 #图片像素
plt.rcParams['figure.dpi'] = 100 #分辨率
lw = 2
plt.plot(range(len(train_auc_log)),train_auc_log, color='darkorange',
         lw=lw, label="train's binary_logloss")
plt.plot(range(len(val_auc_log)),val_auc_log, color='blue',
         lw=lw, label="valid's binary_logloss")
# plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
plt.xlabel('Boost round')
plt.ylabel("Valid's binary_logloss")
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
# save best round results to csv
bst_round = np.argmax(evals_result['valid']['auc'])
trn_auc = evals_result['train']['auc'][bst_round]
trn_loss = evals_result['train']['binary_logloss'][bst_round]
val_auc = evals_result['valid']['auc'][bst_round]
val_loss = evals_result['valid']['binary_logloss'][bst_round]

# %%
print('Best Round: %d'%bst_round)
print('Training loss: %.5f, Validation loss: %.5f'%(trn_loss, val_loss))
print('Training AUC : %.5f, Validation AUC : %.5f'%(trn_auc, val_auc))

# save model to file
model_save_path = './models/trn_auc' + str(trn_auc)[:5] + '_' + 'val_auc' + str(val_auc)[:5] + '.txt'
print('Save model to file: {}'.format(model_save_path))
gbm.save_model(model_save_path)
# Out:
# Best Round: 788
# Training loss: 0.27387, Validation loss: 0.30967
# Training AUC : 0.86469, Validation AUC : 0.74480
# Save model to file: ./models/trn_auc0.864_val_auc0.744.txt

# %%
feature_importance = pd.DataFrame({'name':gbm.feature_name(), 'importance':gbm.feature_importance()}).sort_values(by='importance', ascending=False)
feature_importance.to_csv('./feat_importance.csv', index=False)
# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(15, 5)
plt.rcParams['savefig.dpi'] = 50 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率
feature_importance.plot(x='name', y='importance',kind='barh')
# plt.savefig('plot123_2.png', dpi=300) 
plt.show()

# %% [markdown]
# #### Using best model for Testing

# %%
# load model to predict
print('Load model to predict')
# gbm = lgb.Booster(model_file=model_save_path)
                  
predictions = gbm.predict(x_test)

y_pred = predictions >= 0.5
# print(y_pred[:10])

from sklearn.metrics import accuracy_score, confusion_matrix
# print(accuracy_score(y_test, y_pred))
print(classification_report(y_true=y_test, y_pred=y_pred))

# AUC 
fpr, tpr,_ = roc_curve(y_test, predictions)
roc_auc = auc(fpr, tpr)
print("roc_auc: ",roc_auc)

# plot ROC
plt.figure()
plt.rcParams['savefig.dpi'] = 50 #图片像素
plt.rcParams['figure.dpi'] = 100 #分辨率
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# Load model to predict
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.94       476
#           1       0.79      0.28      0.41        80
#
# avg / total       0.88      0.88      0.86       556
#
# roc_auc:  0.7368960084033613
