# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib
from sklearn.metrics import roc_curve, auc
import seaborn as sns

import lightgbm as lgb
import utils

#supression warnings
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# ### Load data

# %%
data_path = './data/jlr_all_user_processed.xlsx'
df = pd.read_excel(data_path)
df.head(3)
# Out:
#       user_id  follow_count  fans_count  gender birthday  location  level  \
# 0     oden123             0           0       2      NaT         1      1
# 1   生活1934626             2           4       2      NaT         2      1
# 2  wangzi1125             0           1       2      NaT         3      1
#
#   registration_time  properties  mileage     ...      \
# 0        2018-03-26           1     4430     ...
# 1        2012-05-07           1     4270     ...
# 2        2017-06-18           1     2090     ...
#
#                                      car_friend_zone label car_like  \
# 0                                                NaN  True        1
# 1  [{'名称': '汽车之家甘肃论坛车友会', '人数': 672, '创建时间': '201...  True        2
# 2                                                NaN  True        3
#
#   excellent_post_count all_post_count  regis_year  regis_month  regis_day  \
# 0                    0              0        2018            3          3
# 1                    0              0        2012            5          5
# 2                    0              1        2017            6          6
#
#         date  date_delta
# 0 2018-03-26        4522
# 1 2012-05-07        2373
# 2 2017-06-18        4241
#
# [3 rows x 24 columns]

# %%
# df.keys(), df.dtypes

# %% [markdown]
# ### Data choosing
# we choose some features to build the machine learning model

# %%
x = df.drop(columns=[
                      'user_id',
#                      'follow_count',
#                      'fans_count', 
                     'gender', 
                      'birthday',
#                      'location',
                     'level',
                      'registration_time',
                     'properties',
#                      'mileage',
                      'post',
                      'cars',
                      'koubei_post',
                      'gas_mileage',
                      'car_friend_zone',
                      'label',
#                      'car_like', 
                     'excellent_post_count',
                     'all_post_count',
                      'regis_year',
                      'regis_month',
                      'regis_day', 
                      'date',
#                      'date_delta'
                     ])
x.head(2)
# Out:
#    follow_count  fans_count  location  mileage  car_like  date_delta
# 0             0           0         1     4430         1        4522
# 1             2           4         2     4270         2        2373

# %%
# faeture heat map
import matplotlib.pyplot as plt
import seaborn as sns
# data = pd.read_csv("../input/car_crashes.csv")
data = x.corr()
sns.heatmap(data)
plt.show()

# %%
y = df['label'].astype('uint8')
utils.exploreCat(df, 'label')
# Out:
# <div id="bda74785-4e92-4e06-91c2-aa1d38845e75" style="height: 400px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'bda74785-4e92-4e06-91c2-aa1d38845e75',
#             [{"hoverinfo": "all", "labels": [false, true], "marker": {"colors": ["#96D38C", "#FEBFB3"], "line": {"color": "#fff", "width": 2}}, "textfont": {"size": 12}, "textinfo": "value", "values": [4830.0, 725.0], "type": "pie", "uid": "4d3b5d4a-a176-11e8-8290-6c40089fb510"}],
#             {"height": 400, "title": "label"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('bda74785-4e92-4e06-91c2-aa1d38845e75',{});}).then(function(){Plotly.animate('bda74785-4e92-4e06-91c2-aa1d38845e75');})
#         });</script>

# %%
# dataset size
_x, _y = np.array(x).astype('int'), np.array(y).astype('int')
_x.shape, _y.shape
# Out:
# ((5555, 6), (5555,))

# %% [markdown]
# ### Split dataset into train/validation/test set
# train:validation:test = 8:1:1

# %%
x_train, x_test, y_train, y_test = train_test_split(_x, _y, test_size=0.2,  random_state = 42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5,  random_state = 42)

# %%
print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (4444, 6) (555, 6) (556, 6)

# %%
# positive/negative propotion in dataset
print("In train set, positive : negative = {}:{}=1:{} ".format(sum(y_train==1),sum(y_train==0), sum(y_train==0)/sum(y_train==1)))
print("In validation set, positive : negative = {}:{}=1:{}".format(sum(y_val==1),sum(y_val==0), sum(y_val==0)/sum(y_val==1)))
print("In test set, positive : negative = {}:{}=1:{}".format(sum(y_test==1),sum(y_test==0),sum(y_test==0)/sum(y_test==1)))
# Out:
# In train set, positive : negative = 578:3866=1:6.688581314878893
# In validation set, positive : negative = 67:488=1:7.2835820895522385
# In test set, positive : negative = 80:476=1:5.95

# %% [markdown]
# ### Build SVM model then train with above dataset

# %%
clf = SVC(C=0.8, kernel='rbf', class_weight='balanced')

# %%
clf.fit(x_train, y_train)
# Out:
# SVC(C=0.8, cache_size=200, class_weight='balanced', coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
pred = clf.predict(x_test)

# %%
print(classification_report(y_true=y_test, y_pred=pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.85      0.92      0.88       476
#           1       0.03      0.01      0.02        80
#
# avg / total       0.73      0.79      0.76       556

# %% [markdown]
# ### Build lightgbm model and train with above dataset

# %%
# Lightgbm dataset construction

# train_data = lgb.Dataset(x_train, label=y_train)
# val_data = lgb.Dataset(x_val, label=y_val)
# test_data = lgb.Dataset(x_test, label = y_test)

feature_name = list(x.keys())
categorical_feature = [
#                        'gender',
                       'location',
#                        'level', 
#                        'properties', 
                       'car_like',
                     #'regis_year', 'regis_month', 'regis_day',
                                            ]
train_data = lgb.Dataset(x_train, 
                         label=y_train,
                         feature_name=feature_name,
                         categorical_feature=categorical_feature,
                        )
val_data = lgb.Dataset(x_val,
                       label=y_val,
                       feature_name=feature_name,
                       categorical_feature=categorical_feature,
                      )
test_data = lgb.Dataset(x_test, 
                        label = y_test,
                        feature_name=feature_name,
                        categorical_feature=categorical_feature,
                       )
# feature_name, categorical_feature

# %% [markdown]
# #### Setting parameters

# %%
# para searching
params = {
    'boosting_type': 'gbdt',  # np.random.choice(['dart', 'gbdt']),
    'objective': 'binary',
    'metric': ['binary_logloss', 'auc'], 
    
    'learning_rate': 0.30,
    
    'num_leaves': np.random.randint(10,12),
    'max_depth': np.random.randint(7,10),
    'min_data_in_leaf': int(2 ** (np.random.rand()*1.5 + 5)),
    
    'feature_fraction': np.random.rand()*0.35+0.65,
    'bagging_fraction': np.random.rand()*0.35+0.65,
    'bagging_freq': 1,
    
    'lambda_l1': 10 ** (np.random.rand() * 4),
    'lambda_l2': 10 ** (np.random.rand() * 3 + 2),
    'min_gain_to_split': 0.0,
    'min_sum_hessian_in_leaf': 0.1,
    
    'num_threads': 16,
    'verbose': 0,
    'is_training_metric': 'True'
}
print('Hyper-parameters:')
print(params)
# Out:
# Hyper-parameters:
# {'boosting_type': 'gbdt', 'objective': 'binary', 'metric': ['binary_logloss', 'auc'], 'learning_rate': 0.3, 'num_leaves': 11, 'max_depth': 7, 'min_data_in_leaf': 52, 'feature_fraction': 0.6738689371062005, 'bagging_fraction': 0.8289967992224982, 'bagging_freq': 1, 'lambda_l1': 8.115978557126892, 'lambda_l2': 17873.78060382777, 'min_gain_to_split': 0.0, 'min_sum_hessian_in_leaf': 0.1, 'num_threads': 16, 'verbose': 0, 'is_training_metric': 'True'}

# %% [markdown]
# #### Training

# %%
evals_result = {}  # dict to store evaluation results of all the items in `valid_sets`

gbm = lgb.train(params, 
                train_data, 
                num_boost_round=10000, 
                valid_sets=[train_data, val_data], 
                valid_names = ['train', 'valid'], 
                evals_result=evals_result, 
                early_stopping_rounds=3000, 
                verbose_eval=100)
# Out:
# Training until validation scores don't improve for 3000 rounds.
# [100]	train's auc: 0.788469	train's binary_logloss: 0.369613	valid's auc: 0.717626	valid's binary_logloss: 0.356188
# [200]	train's auc: 0.793841	train's binary_logloss: 0.357488	valid's auc: 0.715072	valid's binary_logloss: 0.348215
# [300]	train's auc: 0.798024	train's binary_logloss: 0.348019	valid's auc: 0.718635	valid's binary_logloss: 0.342261
# [400]	train's auc: 0.801153	train's binary_logloss: 0.340007	valid's auc: 0.718528	valid's binary_logloss: 0.337586
# [500]	train's auc: 0.803743	train's binary_logloss: 0.333755	valid's auc: 0.720746	valid's binary_logloss: 0.334111
# [600]	train's auc: 0.80695	train's binary_logloss: 0.328636	valid's auc: 0.722627	valid's binary_logloss: 0.331315
# [700]	train's auc: 0.80945	train's binary_logloss: 0.324461	valid's auc: 0.724431	valid's binary_logloss: 0.329159
# [800]	train's auc: 0.811943	train's binary_logloss: 0.320795	valid's auc: 0.726174	valid's binary_logloss: 0.327277
# [900]	train's auc: 0.813774	train's binary_logloss: 0.317695	valid's auc: 0.72801	valid's binary_logloss: 0.325716
# [1000]	train's auc: 0.815463	train's binary_logloss: 0.314858	valid's auc: 0.728774	valid's binary_logloss: 0.324468
# [1100]	train's auc: 0.817025	train's binary_logloss: 0.312342	valid's auc: 0.730365	valid's binary_logloss: 0.323241
# [1200]	train's auc: 0.818281	train's binary_logloss: 0.310103	valid's auc: 0.732077	valid's binary_logloss: 0.321907
# [1300]	train's auc: 0.819822	train's binary_logloss: 0.308083	valid's auc: 0.732964	valid's binary_logloss: 0.320984
# [1400]	train's auc: 0.821512	train's binary_logloss: 0.306179	valid's auc: 0.733882	valid's binary_logloss: 0.320173
# [1500]	train's auc: 0.822978	train's binary_logloss: 0.304462	valid's auc: 0.735472	valid's binary_logloss: 0.319368
# [1600]	train's auc: 0.824345	train's binary_logloss: 0.302868	valid's auc: 0.736237	valid's binary_logloss: 0.318608
# [1700]	train's auc: 0.825966	train's binary_logloss: 0.301371	valid's auc: 0.736787	valid's binary_logloss: 0.318037
# [1800]	train's auc: 0.827265	train's binary_logloss: 0.29999	valid's auc: 0.738255	valid's binary_logloss: 0.317388
# [1900]	train's auc: 0.828511	train's binary_logloss: 0.298735	valid's auc: 0.738989	valid's binary_logloss: 0.316742
# [2000]	train's auc: 0.8298	train's binary_logloss: 0.297522	valid's auc: 0.739601	valid's binary_logloss: 0.31617
# [2100]	train's auc: 0.830833	train's binary_logloss: 0.29637	valid's auc: 0.740243	valid's binary_logloss: 0.315628
# [2200]	train's auc: 0.832301	train's binary_logloss: 0.295295	valid's auc: 0.740335	valid's binary_logloss: 0.315241
# [2300]	train's auc: 0.833438	train's binary_logloss: 0.294265	valid's auc: 0.740794	valid's binary_logloss: 0.31485
# [2400]	train's auc: 0.834587	train's binary_logloss: 0.293313	valid's auc: 0.741864	valid's binary_logloss: 0.314461
# [2500]	train's auc: 0.835508	train's binary_logloss: 0.29242	valid's auc: 0.742446	valid's binary_logloss: 0.314072
# [2600]	train's auc: 0.836543	train's binary_logloss: 0.291508	valid's auc: 0.742231	valid's binary_logloss: 0.313733
# [2700]	train's auc: 0.837553	train's binary_logloss: 0.290654	valid's auc: 0.742384	valid's binary_logloss: 0.313398
# [2800]	train's auc: 0.8385	train's binary_logloss: 0.289869	valid's auc: 0.742568	valid's binary_logloss: 0.31315
# [2900]	train's auc: 0.83952	train's binary_logloss: 0.289085	valid's auc: 0.742996	valid's binary_logloss: 0.312836
# [3000]	train's auc: 0.840457	train's binary_logloss: 0.288311	valid's auc: 0.743424	valid's binary_logloss: 0.312555
# [3100]	train's auc: 0.841429	train's binary_logloss: 0.287581	valid's auc: 0.743057	valid's binary_logloss: 0.312419
# [3200]	train's auc: 0.842368	train's binary_logloss: 0.286902	valid's auc: 0.742904	valid's binary_logloss: 0.312275
# [3300]	train's auc: 0.843194	train's binary_logloss: 0.28618	valid's auc: 0.743547	valid's binary_logloss: 0.311941
# [3400]	train's auc: 0.844152	train's binary_logloss: 0.285517	valid's auc: 0.7437	valid's binary_logloss: 0.311724
# [3500]	train's auc: 0.84487	train's binary_logloss: 0.284926	valid's auc: 0.743638	valid's binary_logloss: 0.311523
# [3600]	train's auc: 0.845675	train's binary_logloss: 0.284315	valid's auc: 0.744005	valid's binary_logloss: 0.311311
# [3700]	train's auc: 0.846484	train's binary_logloss: 0.283717	valid's auc: 0.744036	valid's binary_logloss: 0.311163
# [3800]	train's auc: 0.847289	train's binary_logloss: 0.283133	valid's auc: 0.744128	valid's binary_logloss: 0.310941
# [3900]	train's auc: 0.847998	train's binary_logloss: 0.282578	valid's auc: 0.744709	valid's binary_logloss: 0.310741
# [4000]	train's auc: 0.848769	train's binary_logloss: 0.282052	valid's auc: 0.744923	valid's binary_logloss: 0.310586
# [4100]	train's auc: 0.849614	train's binary_logloss: 0.281509	valid's auc: 0.744892	valid's binary_logloss: 0.310526
# [4200]	train's auc: 0.850226	train's binary_logloss: 0.280967	valid's auc: 0.745137	valid's binary_logloss: 0.31037
# [4300]	train's auc: 0.851025	train's binary_logloss: 0.280474	valid's auc: 0.744862	valid's binary_logloss: 0.310382
# [4400]	train's auc: 0.851579	train's binary_logloss: 0.280012	valid's auc: 0.744954	valid's binary_logloss: 0.310285
# [4500]	train's auc: 0.852249	train's binary_logloss: 0.279515	valid's auc: 0.744954	valid's binary_logloss: 0.310143
# [4600]	train's auc: 0.852884	train's binary_logloss: 0.279091	valid's auc: 0.74477	valid's binary_logloss: 0.310084
# [4700]	train's auc: 0.853491	train's binary_logloss: 0.278639	valid's auc: 0.744984	valid's binary_logloss: 0.310002
# [4800]	train's auc: 0.85413	train's binary_logloss: 0.278195	valid's auc: 0.745015	valid's binary_logloss: 0.30989
# [4900]	train's auc: 0.854763	train's binary_logloss: 0.277776	valid's auc: 0.745015	valid's binary_logloss: 0.309816
# [5000]	train's auc: 0.855346	train's binary_logloss: 0.277343	valid's auc: 0.745382	valid's binary_logloss: 0.309814
# [5100]	train's auc: 0.855899	train's binary_logloss: 0.27694	valid's auc: 0.745626	valid's binary_logloss: 0.309738
# [5200]	train's auc: 0.856568	train's binary_logloss: 0.276534	valid's auc: 0.745351	valid's binary_logloss: 0.309721
# [5300]	train's auc: 0.857123	train's binary_logloss: 0.276145	valid's auc: 0.745626	valid's binary_logloss: 0.309648
# [5400]	train's auc: 0.857749	train's binary_logloss: 0.275747	valid's auc: 0.74584	valid's binary_logloss: 0.309521
# [5500]	train's auc: 0.858305	train's binary_logloss: 0.27536	valid's auc: 0.745626	valid's binary_logloss: 0.309485
# [5600]	train's auc: 0.858867	train's binary_logloss: 0.274966	valid's auc: 0.745657	valid's binary_logloss: 0.309505
# [5700]	train's auc: 0.859465	train's binary_logloss: 0.274586	valid's auc: 0.745779	valid's binary_logloss: 0.309435
# [5800]	train's auc: 0.859951	train's binary_logloss: 0.274253	valid's auc: 0.745993	valid's binary_logloss: 0.309432
# [5900]	train's auc: 0.860508	train's binary_logloss: 0.27391	valid's auc: 0.746391	valid's binary_logloss: 0.309432
# [6000]	train's auc: 0.861044	train's binary_logloss: 0.273559	valid's auc: 0.74633	valid's binary_logloss: 0.309427
# [6100]	train's auc: 0.861684	train's binary_logloss: 0.273194	valid's auc: 0.746391	valid's binary_logloss: 0.30945
# [6200]	train's auc: 0.862249	train's binary_logloss: 0.272832	valid's auc: 0.746544	valid's binary_logloss: 0.309397
# [6300]	train's auc: 0.8627	train's binary_logloss: 0.272481	valid's auc: 0.746666	valid's binary_logloss: 0.309386
# [6400]	train's auc: 0.863184	train's binary_logloss: 0.272136	valid's auc: 0.747186	valid's binary_logloss: 0.309384
# [6500]	train's auc: 0.863693	train's binary_logloss: 0.271806	valid's auc: 0.747339	valid's binary_logloss: 0.309434
# [6600]	train's auc: 0.864237	train's binary_logloss: 0.271476	valid's auc: 0.747553	valid's binary_logloss: 0.309467
# [6700]	train's auc: 0.864646	train's binary_logloss: 0.27116	valid's auc: 0.747614	valid's binary_logloss: 0.309483
# [6800]	train's auc: 0.865136	train's binary_logloss: 0.270832	valid's auc: 0.747553	valid's binary_logloss: 0.309554
# [6900]	train's auc: 0.865617	train's binary_logloss: 0.270506	valid's auc: 0.747645	valid's binary_logloss: 0.309566
# [7000]	train's auc: 0.866084	train's binary_logloss: 0.2702	valid's auc: 0.747523	valid's binary_logloss: 0.309544
# [7100]	train's auc: 0.866648	train's binary_logloss: 0.269877	valid's auc: 0.747614	valid's binary_logloss: 0.30961
# [7200]	train's auc: 0.867191	train's binary_logloss: 0.269559	valid's auc: 0.747767	valid's binary_logloss: 0.309646
# [7300]	train's auc: 0.867696	train's binary_logloss: 0.269234	valid's auc: 0.747767	valid's binary_logloss: 0.309662
# [7400]	train's auc: 0.868143	train's binary_logloss: 0.268951	valid's auc: 0.747798	valid's binary_logloss: 0.309692
# [7500]	train's auc: 0.868529	train's binary_logloss: 0.268671	valid's auc: 0.74737	valid's binary_logloss: 0.309774
# [7600]	train's auc: 0.869019	train's binary_logloss: 0.268369	valid's auc: 0.747614	valid's binary_logloss: 0.309824
# [7700]	train's auc: 0.86943	train's binary_logloss: 0.268093	valid's auc: 0.747553	valid's binary_logloss: 0.309936
# [7800]	train's auc: 0.869918	train's binary_logloss: 0.267802	valid's auc: 0.747461	valid's binary_logloss: 0.309973
# [7900]	train's auc: 0.870371	train's binary_logloss: 0.267536	valid's auc: 0.747339	valid's binary_logloss: 0.310023
# [8000]	train's auc: 0.870836	train's binary_logloss: 0.267239	valid's auc: 0.747278	valid's binary_logloss: 0.310087
# [8100]	train's auc: 0.871232	train's binary_logloss: 0.266956	valid's auc: 0.747094	valid's binary_logloss: 0.310123
# [8200]	train's auc: 0.871655	train's binary_logloss: 0.266678	valid's auc: 0.747033	valid's binary_logloss: 0.310205
# [8300]	train's auc: 0.872096	train's binary_logloss: 0.266411	valid's auc: 0.74685	valid's binary_logloss: 0.310259
# [8400]	train's auc: 0.872526	train's binary_logloss: 0.266144	valid's auc: 0.746819	valid's binary_logloss: 0.310285
# [8500]	train's auc: 0.872897	train's binary_logloss: 0.265863	valid's auc: 0.746727	valid's binary_logloss: 0.310327
# [8600]	train's auc: 0.873362	train's binary_logloss: 0.265596	valid's auc: 0.746391	valid's binary_logloss: 0.310426
# [8700]	train's auc: 0.873782	train's binary_logloss: 0.265329	valid's auc: 0.746513	valid's binary_logloss: 0.310455
# [8800]	train's auc: 0.874168	train's binary_logloss: 0.265065	valid's auc: 0.746177	valid's binary_logloss: 0.310549
# [8900]	train's auc: 0.874614	train's binary_logloss: 0.264795	valid's auc: 0.746055	valid's binary_logloss: 0.310652
# [9000]	train's auc: 0.874919	train's binary_logloss: 0.264556	valid's auc: 0.745779	valid's binary_logloss: 0.310735
# [9100]	train's auc: 0.875321	train's binary_logloss: 0.264302	valid's auc: 0.745718	valid's binary_logloss: 0.310851
# [9200]	train's auc: 0.875667	train's binary_logloss: 0.26406	valid's auc: 0.745535	valid's binary_logloss: 0.310982
# [9300]	train's auc: 0.876035	train's binary_logloss: 0.263842	valid's auc: 0.745351	valid's binary_logloss: 0.311087
# Early stopping, best iteration is:
# [6343]	train's auc: 0.862909	train's binary_logloss: 0.272341	valid's auc: 0.74688	valid's binary_logloss: 0.309356

# %%
train_auc_log = evals_result['train']['binary_logloss']
# type(train_auc_log)
# len(train_auc_log)
val_auc_log = evals_result['valid']['binary_logloss']

# plot training logs
plt.figure()
plt.rcParams['savefig.dpi'] = 50 #图片像素
plt.rcParams['figure.dpi'] = 100 #分辨率
lw = 2
plt.plot(range(len(train_auc_log)),train_auc_log, color='darkorange',
         lw=lw, label="train's binary_logloss")
plt.plot(range(len(val_auc_log)),val_auc_log, color='blue',
         lw=lw, label="valid's binary_logloss")
# plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
plt.xlabel('Boost round')
plt.ylabel("Valid's binary_logloss")
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()

# %%
# save best round results to csv
bst_round = np.argmax(evals_result['valid']['auc'])
trn_auc = evals_result['train']['auc'][bst_round]
trn_loss = evals_result['train']['binary_logloss'][bst_round]
val_auc = evals_result['valid']['auc'][bst_round]
val_loss = evals_result['valid']['binary_logloss'][bst_round]

# %%
print('Best Round: %d'%bst_round)
print('Training loss: %.5f, Validation loss: %.5f'%(trn_loss, val_loss))
print('Training AUC : %.5f, Validation AUC : %.5f'%(trn_auc, val_auc))

# save model to file
model_save_path = './models/trn_auc' + str(trn_auc)[:5] + '_' + 'val_auc' + str(val_auc)[:5] + '.txt'
print('Save model to file: {}'.format(model_save_path))
gbm.save_model(model_save_path)
# Out:
# Best Round: 7220
# Training loss: 0.26949, Validation loss: 0.30962
# Training AUC : 0.86727, Validation AUC : 0.74792
# Save model to file: ./models/trn_auc0.867_val_auc0.747.txt

# %%
feature_importance = pd.DataFrame({'name':gbm.feature_name(), 'importance':gbm.feature_importance()}).sort_values(by='importance', ascending=False)
feature_importance.to_csv('./feat_importance.csv', index=False)
# fig = matplotlib.pyplot.gcf()
# fig.set_size_inches(15, 5)
plt.rcParams['savefig.dpi'] = 50 #图片像素
plt.rcParams['figure.dpi'] = 200 #分辨率
feature_importance.plot(x='name', y='importance',kind='barh')
# plt.savefig('plot123_2.png', dpi=300) 
plt.show()

# %% [markdown]
# #### Using best model for Testing

# %%
# load model to predict
print('Load model to predict')
gbm = lgb.Booster(model_file=model_save_path)
                  
y_pred = gbm.predict(x_test)
# print(y_pred[:10])

y_pred = y_pred >= 0.5
# print(y_pred[:10])

from sklearn.metrics import accuracy_score, confusion_matrix
# print(accuracy_score(y_test, y_pred))
print(classification_report(y_true=y_test, y_pred=y_pred))

# AUC 
fpr, tpr,_ = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
print("roc_auc: ",roc_auc)

# plot ROC
plt.figure()
plt.rcParams['savefig.dpi'] = 50 #图片像素
plt.rcParams['figure.dpi'] = 100 #分辨率
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC')
plt.legend(loc="lower right")
plt.show()
# Out:
# Load model to predict
#              precision    recall  f1-score   support
#
#           0       0.89      0.99      0.94       476
#           1       0.79      0.29      0.42        80
#
# avg / total       0.88      0.89      0.86       556
#
# roc_auc:  0.6374474789915967
